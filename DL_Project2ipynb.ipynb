# %%
import tensorflow
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Embedding, SpatialDropout1D
from tensorflow.keras.layers import SimpleRNN # new! 
from tensorflow.keras.callbacks import ModelCheckpoint
import os
from sklearn.metrics import roc_auc_score 
import matplotlib.pyplot as plt 
import re
import pickle
import sklearn
import pandas as pd
import numpy as np
import holoviews as hv
import nltk 
from bokeh.io import output_notebook
output_notebook()

from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from xgboost import XGBClassifier
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
# load doc into memory
def read_file(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# %%
# load document
textfile = '/pg1497.txt'
text = read_file(textfile)
print(text[:400]) # Printing the few lines
# Out:
# ﻿The Project Gutenberg eBook of The Republic, by Plato
#
# This eBook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this eBook or online at
# www.gutenberg.org. If you are not located in the United Sta

# %%
nltk.download('punkt')
nltk.download('stopwords')

stemmer = SnowballStemmer("english")
stop_words = set(stopwords.words("english"))


def clean_text(text, for_embedding=False):
    """ steps:
        - remove any html tags (< /br> often found)
        - Keep only ASCII + European Chars and whitespace, no digits
        - remove single letter chars
        - convert all whitespaces (tabs etc.) to single wspace
        if not for embedding (but e.g. tdf-idf):
        - all lowercase
        - remove stopwords, punctuation and stemm
    """
    RE_WSPACE = re.compile(r"\s+", re.IGNORECASE)
    RE_TAGS = re.compile(r"<[^>]+>")
    RE_ASCII = re.compile(r"[^A-Za-zÀ-ž ]", re.IGNORECASE)
    RE_SINGLECHAR = re.compile(r"\b[A-Za-zÀ-ž]\b", re.IGNORECASE)
    if for_embedding:
        # Keep punctuation
        RE_ASCII = re.compile(r"[^A-Za-zÀ-ž,.!? ]", re.IGNORECASE)
        RE_SINGLECHAR = re.compile(r"\b[A-Za-zÀ-ž,.!?]\b", re.IGNORECASE)

    text = re.sub(RE_TAGS, " ", text)
    text = re.sub(RE_ASCII, " ", text)
    text = re.sub(RE_SINGLECHAR, " ", text)
    text = re.sub(RE_WSPACE, " ", text)

    word_tokens = word_tokenize(text)
    words_tokens_lower = [word.lower() for word in word_tokens]

    if for_embedding:
        # no stemming, lowering and punctuation / stop words removal
        words_filtered = word_tokens
    else:
        words_filtered = [
            stemmer.stem(word) for word in words_tokens_lower if word not in stop_words
        ]

    text_clean = " ".join(words_filtered)
    return text_clean
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
clean_text(text)
# Out:
# 'project gutenberg ebook republ plato ebook use anyon anywher unit state part world cost almost restrict whatsoev may copi give away use term project gutenberg licens includ ebook onlin www gutenberg org locat unit state check law countri locat use ebook titl republ author plato translat jowett releas date octob ebook recent updat septemb languag english produc sue asscher david widger start project gutenberg ebook republ republ plato translat benjamin jowett note see also republ plato jowett ebook content introduct analysi republ person dialogu book book ii book iii book iv book book vi book vii book viii book ix book introduct analysi republ plato longest work except law certain greatest nearer approach modern metaphys philebus sophist politicus statesman ideal form institut state clear drawn law work art symposium protagora higher excel dialogu plato larg view perfect style show equal knowledg world contain thought new well old one age nowher plato deeper ironi greater wealth humour imageri dramat power write attempt made interweav life specul connect polit philosophi republ centr around dialogu may group philosophi reach highest point cp especi book vi vii ancient thinker ever attain plato among greek like bacon among modern first conceiv method knowledg although neither alway distinguish bare outlin form substanc truth content abstract scienc yet realiz greatest metaphys genius world seen ancient thinker germ futur knowledg contain scienc logic psycholog suppli mani instrument thought age base upon analys socrat plato principl definit law contradict fallaci argu circl distinct essenc accid thing notion mean end caus condit also divis mind ration concupisc irasc element pleasur desir necessari unnecessari great form thought found republ probabl first invent plato greatest logic truth one writer philosophi apt lose sight differ word thing strenuous insist cp rep polit cratyl ff although alway avoid confus write rep bind truth logic formula logic still veil metaphys scienc imagin contempl truth exist unlik doctrin syllog aristotl claim discov soph elenchi neither must forget republ third part still larger design includ ideal histori athen well polit physic philosophi fragment critia given birth world famous fiction second import tale troy legend arthur said fact inspir earli navig sixteenth centuri mythic tale subject histori war athenian island atlanti suppos found upon unfinish poem solon would stood relat write logograph poem homer would told struggl liberti cp tim intend repres conflict persia hella may judg nobl commenc timaeus fragment critia third book law manner plato would treat high argument guess great design abandon perhap plato becam sensibl incongru fictiti histori lost interest advanc year forbad complet may pleas fanci imaginari narrat ever finish found plato sympathis struggl hellen independ cp law iii ff sing hymn triumph marathon salami perhap make reflect herodotus contempl growth athenian empir brave thing freedom speech made athenian far exceed everi state hella great probabl attribut victori ancient good order athen favor apollo athen cp introd critia plato may regard captain arhchegoz leader good band follow republ found origin cicero de republica st augustin citi god utopia sir thoma numer imaginari state frame upon model extent aristotl aristotelian school indebt polit littl recognis recognit necessari made aristotl two philosoph common conscious probabl element plato remain still undetect aristotl english philosophi mani affin may trace work cambridg platonist great origin writer like berkeley coleridg plato idea truth higher experi mind bear wit convict generat enthusiast assert perhap gain ground greek author renaiss brought new life world plato greatest influenc republ plato also first treatis upon educ write milton lock rousseau jean paul goeth legitim descend like dant bunyan revel anoth life like bacon profound impress uniti knowledg earli church exercis real influenc theolog reviv literatur  ...

# %%
def clean(doc):
	# replace '--' with a space ' '
	doc = doc.replace('--', ' ')
	# split into tokens by white space
	tokens = doc.split()
	# remove punctuation from each token
	table = str.maketrans('', '', string.punctuation)
	tokens = [w.translate(table) for w in tokens]
	# remove remaining tokens that are not alphabetic
	tokens = [word for word in tokens if word.isalpha()]
	# make lower case
	tokens = [word.lower() for word in tokens]
	return tokens

# %%
# clean document

import string
 
tokens = clean(text)
print(tokens[:600])
print('Total Tokens: %d' % len(tokens))
print('Unique Tokens: %d' % len(set(tokens)))
# Out:
# ['project', 'gutenberg', 'ebook', 'of', 'the', 'republic', 'by', 'plato', 'this', 'ebook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'united', 'states', 'and', 'most', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever', 'you', 'may', 'copy', 'it', 'give', 'it', 'away', 'or', 'reuse', 'it', 'under', 'the', 'terms', 'of', 'the', 'project', 'gutenberg', 'license', 'included', 'with', 'this', 'ebook', 'or', 'online', 'at', 'wwwgutenbergorg', 'if', 'you', 'are', 'not', 'located', 'in', 'the', 'united', 'states', 'you', 'will', 'have', 'to', 'check', 'the', 'laws', 'of', 'the', 'country', 'where', 'you', 'are', 'located', 'before', 'using', 'this', 'ebook', 'title', 'the', 'republic', 'author', 'plato', 'translator', 'b', 'jowett', 'release', 'date', 'october', 'ebook', 'most', 'recently', 'updated', 'september', 'language', 'english', 
# Total Tokens: 216373
# Unique Tokens: 10487

# %%
# organize into sequences of tokens
length = 50 + 1
sequences = list()
for i in range(length, len(tokens)):
	# select sequence of tokens
	seq = tokens[i-length:i]
	# convert into a line
	line = ' '.join(seq)
	# store
	sequences.append(line)
print('Total Sequences: %d' % len(sequences))
# Out:
# Total Sequences: 216322

# %%
# save tokens to file, one dialog per line
def save_doc(lines, filename):
	data = '\n'.join(lines)
	file = open(filename, 'w')
	file.write(data)
	file.close()

# %%
# save sequences to file
out_filename = 'republic_sequences.txt'
save_doc(sequences, out_filename)

# %%
in_filename = 'republic_sequences.txt'
txt = read_file(in_filename)
lines = txt.split('\n')

# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from numpy import array
from pickle import dump
from keras.preprocessing.text import Tokenizer
from pickle import dump
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Embedding

# %%
# integer encode sequences of words
tokenizer = Tokenizer()
tokenizer.fit_on_texts(lines)
sequences = tokenizer.texts_to_sequences(lines)

# %%
# vocabulary size
vocab_size = len(tokenizer.word_index) + 1

# %%
# separate into input and output
sequences = array(sequences)
X, y = sequences[:,:-1], sequences[:,-1]
y = to_categorical(y, num_classes=vocab_size)
seq_length = X.shape[1]

# %%
# define model
model = Sequential()
model.add(Embedding(vocab_size, 50, input_length=seq_length))
model.add(LSTM(100, return_sequences=True))

model.add(LSTM(100))

model.add(Dense(300, activation='relu'))
model.add(Dense(vocab_size, activation='softmax'))
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 50, 50)            524400
#
#  lstm (LSTM)                 (None, 50, 100)           60400
#
#  lstm_1 (LSTM)               (None, 100)               80400
#
#  dense (Dense)               (None, 300)               30300
#
#  dense_1 (Dense)             (None, 10488)             3156888
#
# =================================================================
# Total params: 3,852,388
# Trainable params: 3,852,388
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit model
model.fit(X, y, batch_size=128, epochs=100)
# Out:
# Epoch 1/100
# 1691/1691 [==============================] - 595s 349ms/step - loss: 6.1257 - accuracy: 0.0975
# Epoch 2/100
# 1691/1691 [==============================] - 579s 342ms/step - loss: 5.6645 - accuracy: 0.1324
# Epoch 3/100
# 1691/1691 [==============================] - 562s 332ms/step - loss: 5.4260 - accuracy: 0.1539
# Epoch 4/100
# 1691/1691 [==============================] - 558s 330ms/step - loss: 5.2659 - accuracy: 0.1645
# Epoch 5/100
# 1691/1691 [==============================] - 557s 329ms/step - loss: 5.1366 - accuracy: 0.1720
# Epoch 6/100
# 1691/1691 [==============================] - 562s 332ms/step - loss: 5.0192 - accuracy: 0.1786
# Epoch 7/100
# 1691/1691 [==============================] - 558s 330ms/step - loss: 4.9103 - accuracy: 0.1837
# Epoch 8/100
# 1691/1691 [==============================] - 561s 332ms/step - loss: 4.8147 - accuracy: 0.1872
# Epoch 9/100
# 1691/1691 [==============================] - 578s 342ms/step - loss: 4.7197 - accuracy: 0.1908
# Epoch 10/100
# 1691/1691 [==============================] - 571s 337ms/step - loss: 4.6335 - accuracy: 0.1937
# Epoch 11/100
# 1691/1691 [==============================] - 570s 337ms/step - loss: 4.5518 - accuracy: 0.1971
# Epoch 12/100
# 1691/1691 [==============================] - 570s 337ms/step - loss: 4.4755 - accuracy: 0.1998
# Epoch 13/100
# 1691/1691 [==============================] - 571s 338ms/step - loss: 4.4028 - accuracy: 0.2021
# Epoch 14/100
